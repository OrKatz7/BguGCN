# %%
# !/home/kaor/.conda/envs/mmdet/bin/python main.py --config_file ./config/ultragcn_gowalla_m1.ini
# Out:
# ###################### UltraGCN ######################
# Loading Configuration...
# torch.cuda.is_available() True
# cuda
# load path = ./gowalla_ii_constraint_mat object
# load path = ./gowalla_ii_neighbor_mat object
# Load Configuration OK, show them below
# Configuration:
# {'embedding_dim': 64, 'ii_neighbor_num': 10, 'model_save_path': './ultragcn_gowalla.pt', 'max_epoch': 2000, 'enable_tensorboard': True, 'initial_weight': 0.0001, 'dataset': 'gowalla', 'gpu': '0', 'device': device(type='cuda'), 'lr': 0.0001, 'batch_size': 512, 'early_stop_epoch': 100, 'w1': 1e-06, 'w2': 1.0, 'w3': 1e-06, 'w4': 1.0, 'negative_num': 1500, 'negative_weight': 300.0, 'gamma': 0.0001, 'lambda': 0.0005, 'sampling_sift_pos': False, 'test_batch_size': 2048, 'topk': 20, 'user_num': 29858, 'item_num': 40981}
# cuda
# Total training batches = 1583
# The time for epoch 0 is: train time = 00: 01: 42, test time = 00: 00: 04
# ...

# %%
# !/home/kaor/.conda/envs/mmdet/bin/python main.py --config_file ./config/ultragcn_gowalla_m1.ini
# Out:
# ###################### UltraGCN ######################
# Loading Configuration...
# torch.cuda.is_available() True
# cuda
# load path = ./gowalla_ii_constraint_mat object
# load path = ./gowalla_ii_neighbor_mat object
# Load Configuration OK, show them below
# Configuration:
# {'embedding_dim': 64, 'ii_neighbor_num': 10, 'model_save_path': './ultragcn_gowalla.pt', 'max_epoch': 2000, 'enable_tensorboard': True, 'initial_weight': 0.0001, 'dataset': 'gowalla', 'gpu': '0', 'device': device(type='cuda'), 'lr': 0.0001, 'batch_size': 512, 'early_stop_epoch': 100, 'w1': 1e-06, 'w2': 1.0, 'w3': 1e-06, 'w4': 1.0, 'negative_num': 1500, 'negative_weight': 300.0, 'gamma': 0.0001, 'lambda': 0.0005, 'sampling_sift_pos': False, 'test_batch_size': 2048, 'topk': 20, 'user_num': 29858, 'item_num': 40981}
# cuda
# Total training batches = 1583
# 100%|███████████████████████████████████████| 1583/1583 [01:34<00:00, 16.82it/s]
# The time for epoch 0 is: train time = 00: 01: 34, test time = 00: 00: 07
# ...

# %%
# !/home/kaor/.conda/envs/openmmlab/bin/python main.py --config_file ./config/ultragcn_amazonbooks_m1.ini
